# %%
cd rmit/apt/assignment3
# Out:
# [Errno 2] No such file or directory: 'rmit/apt/assignment3'
# /Users/hooniesun/rmit/apt/assignment3

# %%
import pandas as pd

# %%
with open('web2', 'r') as f:
    words = f.read().splitlines()

ser = pd.Series(words)

# %%
ser
# Out:
# 0                  A
# 1                  a
# 2                 aa
# 3                aal
# 4              aalii
#              ...
# 235881        zythem
# 235882        Zythia
# 235883        zythum
# 235884       Zyzomys
# 235885    Zyzzogeton
# Length: 235886, dtype: object

# %%
ser = ser[ser.str.len() <= 15]

# %%
ser = ser.str.upper()

# %%
words = ser.unique()

# %%
words
# Out:
# array(['A', 'AA', 'AAL', ..., 'ZYTHUM', 'ZYZOMYS', 'ZYZZOGETON'],
#       dtype=object)

# %%
words = words.tolist()

# %%
words
# Out:
# ['A',
#  'AA',
#  'AAL',
#  'AALII',
#  'AAM',
#  'AANI',
#  'AARDVARK',
#  'AARDWOLF',
#  'AARON',
#  'AARONIC',
#  'AARONICAL',
#  'AARONITE',
#  'AARONITIC',
#  'AARU',
#  'AB',
#  'ABA',
#  'ABABDEH',
#  'ABABUA',
#  'ABAC',
#  'ABACA',
#  'ABACATE',
#  'ABACAY',
#  'ABACINATE',
#  'ABACINATION',
#  'ABACISCUS',
#  'ABACIST',
#  'ABACK',
#  'ABACTINAL',
#  'ABACTINALLY',
#  'ABACTION',
#  'ABACTOR',
#  'ABACULUS',
#  'ABACUS',
#  'ABADITE',
#  'ABAFF',
#  'ABAFT',
#  'ABAISANCE',
#  'ABAISER',
#  'ABAISSED',
#  'ABALIENATE',
#  'ABALIENATION',
#  'ABALONE',
#  'ABAMA',
#  'ABAMPERE',
#  'ABANDON',
#  'ABANDONABLE',
#  'ABANDONED',
#  'ABANDONEDLY',
#  'ABANDONEE',
#  'ABANDONER',
#  'ABANDONMENT',
#  'ABANIC',
#  'ABANTES',
#  'ABAPTISTON',
#  'ABARAMBO',
#  'ABARIS',
#  'ABARTHROSIS',
#  'ABARTICULAR',
#  'ABARTICULATION',
#  'ABAS',
#  'ABASE',
#  'ABASED',
#  'ABASEDLY',
#  'ABASEDNESS',
#  'ABASEMENT',
#  'ABASER',
#  'ABASGI',
#  'ABASH',
#  'ABASHED',
#  'ABASHEDLY',
# ...

# %%
with open('words', 'w') as f:
    f.writelines('\n'.join(words))

# %%
for word in words[:5]:
    for i in range(len(word)):
        # If there is more letter to process after word[i]
        if (i != len(word) - 1):
            if word[i] not in p:
                p[word[i]] = {}
        else:
            if word not in p:
                p[word] =
# Out:
#   File "/var/folders/wj/lrcdk1m954s_h_tgtdcn31hw0000gn/T/ipykernel_3104/2619434337.py", line 7
#     elif (i )
#              ^
# SyntaxError: invalid syntax
